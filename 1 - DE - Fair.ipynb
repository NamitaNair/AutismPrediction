# %% [markdown]
# ## 1. Set up Drive

# %%
# Mount drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## 2. Import Libraries

# %%
# Make imports

import requests
import zipfile
import os
from google.colab import files

# %% [markdown]
# ## 3. Download data

# %% [markdown]
# 1 - Move to the current directory

# %%
cd "gdrive/MyDrive/Projects/1 - Numericals/Autism Prediction Challenge/2 - Production/data"
# Out:
# /content/gdrive/MyDrive/Projects/1 - Numericals/Autism Prediction Challenge/2 - Production/data

# %% [markdown]
# 2 - Upload Kaggle API Key

# %%
#Load Kaggle API

files.upload()
# Out:
#      <input type="file" id="files-e33887eb-e9bb-4b55-83e4-df100e22f29b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e33887eb-e9bb-4b55-83e4-df100e22f29b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"iamnamita","key":"9a06e3cd6033507fd1a88b855279f79f"}'}

# %% [markdown]
# 3 - Set up Kaggle

# %%
# Set up Kaggle

# !pip install kaggle==1.5.6
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json  # set permission
# Out:
# ...
#      |████████████████████████████████| 58 kB 2.7 MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.6-py3-none-any.whl size=72858 sha256=e227c7eb2ebf7f83545f992bde2b5c431247fc21916837452d5083068d414a90
#   Stored in directory: /root/.cache/pip/wheels/aa/e7/e7/eb3c3d514c33294d77ddd5a856bdd58dc9c1fabbed59a02a2b
# Successfully built kaggle
# ...
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.12
#     Uninstalling kaggle-1.5.12:
#       Successfully uninstalled kaggle-1.5.12
# ...
# kaggle.json

# %% [markdown]
# 4 - Download data

# %%
# !kaggle competitions download -c autism-prediction
# Out:
# ...
#   0% 0.00/26.2k [00:00<?, ?B/s]
# 100% 26.2k/26.2k [00:00<00:00, 3.26MB/s]

# %%
# !ls
# Out:
# autism-prediction.zip

# %% [markdown]
# 5 - Uncompress data

# %%
# !unzip autism-prediction
# Out:
# Archive:  autism-prediction.zip
#   inflating: Autism-prediction/sample_submission.csv
#   inflating: Autism-prediction/test.csv
#   inflating: Autism-prediction/train.csv

# %% [markdown]
# 6 - Check files

# %%
ls
# Out:
# Autism-prediction/  autism-prediction.zip

# %% [markdown]
# 7 - Move the files inside Autism-prediction folder to the data folder manually

# %%
ls
# Out:
# Autism-prediction/     sample_submission.csv  train.csv
# autism-prediction.zip  test.csv
